# %%
import pandas as pd

# %%
df = pd.read_parquet("backtest_result.parquet")
df
# Out:
#                 port_ret  bench_ret       nav  bench_nav
# rebalance_date
# 20190423       -0.131006  -0.139712  0.868994   0.860288
# 20190524        0.015493   0.037682  0.882457   0.892706
# 20190624       -0.031709  -0.049287  0.854475   0.848707
# 20190722       -0.034469   0.020613  0.825022   0.866202
# 20190819        0.045335   0.054443  0.862425   0.913361
# ...                  ...        ...       ...        ...
# 20241129        0.031842   0.008070  1.289152   1.048170
# 20241227       -0.012048  -0.052520  1.273621   0.993120
# 20250127       -0.007531   0.062313  1.264029   1.055004
# 20250304        0.039124  -0.007542  1.313484   1.047048
# 20250401       -0.038295  -0.044295  1.263183   1.000669
#
# [73 rows x 4 columns]
